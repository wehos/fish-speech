# %%
from IPython.display import Audio, display
import sys
system_prompt = "A chat between a curious user and an artificial intelligence assistant. The assistant gives helpful, detailed, and polite answers to the user's questions."
pre_prompt = 'Speak out the text below.\n'
# text = 'Last week I went to a theatre. I had a very good seat. The play was very funny, but I did not enjoy it. A young couple was sitting behind me. They were talking loudly. I got very angry because I cannot hear the actors.'
# text = 'Today is a nice day. How are you today?<\s>'
text = '### Script\n你好，吃了吗？\n### Audio\n'
sys.path.append('./fish-speech')

# text = system_prompt + " USER: " + pre_prompt + text + " ASSISTANT: "

# %%
import os
os.environ['CUDA_VISIBLE_DEVICES'] = '2'

# %%
# from collections import OrderedDict
# import torch
# ckpt = torch.load('results/text2semantic_pretrain_dev_audio/checkpoints/last.ckpt/checkpoint/mp_rank_00_model_states.pt')
# # ckpt = torch.load('checkpoint')
# new = OrderedDict()
# for k in ckpt['module']:
#     new[k[6:]] = ckpt['module'][k]
# torch.save(new, 'checkpoints/adapted_20000_vicuna7b.pt')

# %%
from tools.llama.generate import main

feature = main(text, prompt_text=None, prompt_tokens=None, num_samples=1, temperature=1.0, speaker=None,
     max_new_tokens=512, max_length=2048, chunk_length=0, top_k=5, top_p=1, repetition_penalty=1.2, 
     checkpoint_path='checkpoints/adapted_20000_vicuna7b.pt', mode='audio',
    config_name='dual_ar_2_codebook_7b', tokenizer='fishaudio/speech-lm-v1', 
     compile=False, seed=0, half=False, iterative_prompt=False)
# Out:
# 2024-04-26 17:36:20.007 | INFO     | tools.llama.generate:main:633 - Loading model ...
# 2024-04-26 17:37:31.025 | INFO     | tools.llama.generate:load_model:390 - Restored model from checkpoint
# 2024-04-26 17:37:31.027 | INFO     | tools.llama.generate:load_model:394 - Using DualARTransformer
# 2024-04-26 17:37:31.643 | INFO     | tools.llama.generate:main:639 - Time to load model: 71.63 seconds
# Special tokens have been added in the vocabulary, make sure the associated word embeddings are fine-tuned or trained.
# 2024-04-26 17:37:38.488 | INFO     | tools.llama.generate:generate_long:464 - Encoded text: ### Script
# 你好，吃了吗？
# ### Audio
#
# 2024-04-26 17:37:38.488 | INFO     | tools.llama.generate:generate_long:486 - Generating sentence 1/1 of sample 1/1
# 100%|██████████| 511/511 [00:11<00:00, 43.32it/s]
# 2024-04-26 17:37:50.315 | INFO     | tools.llama.generate:generate_long:536 - Generated 512 tokens in 11.83 seconds, 43.29 tokens/sec
# 2024-04-26 17:37:50.316 | INFO     | tools.llama.generate:generate_long:539 - Bandwidth achieved: 329.26 GB/s
# 2024-04-26 17:37:50.316 | INFO     | tools.llama.generate:generate_long:542 - GPU Memory used: 32.05 GB

# %%
feature
# Out:
# tensor([[687, 807, 687,  ..., 647, 670, 903],
#         [984, 984, 992,  ..., 752, 881, 704]], device='cuda:0',
#        dtype=torch.int32)

# %%
from tools.vqgan.inference import vq_main
import torch
import numpy as np

# feature = np.load("codes_0.npy")
# feature = torch.from_numpy(feature).cuda()[None]
with torch.no_grad():
    audio = vq_main(feature)
# audio = audio[0, 0].detach().cpu().numpy()
audio = audio / np.max(np.abs(audio))
# sf.write("test.wav", audio, 44100)
display(Audio(data=audio, rate=44100))

# %%
global_encoded
# Out:
# '<s:0><s:0><s:0><s:0><s:0><s:0><s:0><s:0><s:0><s:0><s:0><s:0><s:0><s:0><s:0><s:0><s:0><s:0><s:0><s:0><s:0><s:0><s:0><s:0><s:0><s:0><s:0><s:0><s:0><s:0><s:0><s:0><s:0><s:0><s:0><s:0><s:0><s:0><s:0><s:0><s:0><s:0><s:0><s:0><s:0><s:0><s:0><s:0><s:0><s:0><s:0><s:0><s:0><s:0><s:0><s:0><s:0><s:0><s:0><s:0><s:0><s:0><s:0><s:0><s:0><s:0><s:0><s:0><s:0><s:0><s:0><s:0><s:0><s:0><s:0><s:0><s:0><s:0><s:0><s:0><s:0><s:0><s:0><s:0><s:0><s:0><s:0><s:0><s:0><s:0><s:0><s:0><s:0><s:0><s:0><s:0><s:0><s:0><s:0><s:0><s:0><s:0><s:0><s:0><s:0><s:0><s:0><s:0><s:0><s:0><s:0><s:0><s:0><s:0><s:0><s:0><s:0><s:0><s:0><s:0><s:0><s:0><s:0><s:0><s:0><s:0><s:0><s:0><s:0><s:0><s:0><s:0><s:0><s:0><s:0><s:0><s:0><s:0><s:0><s:0><s:0><s:0><s:0><s:0><s:0><s:0><s:0><s:0><s:0><s:0><s:0><s:0><s:0><s:0><s:0><s:0><s:0><s:0><s:0><s:0><s:0><s:0><s:0><s:0><s:0><s:0><s:0><s:0><s:0><s:0><s:0><s:0><s:0><s:0><s:0><s:0><s:0><s:0><s:0><s:0><s:0><s:0><s:0><s:0><s:0><s:0><s:0><s:0><s:0><s:0><s:0><s:0><s:0><s:0><s:0><s:0><s:0><s:0><s:0><s:0><s:0><s:0><s:0><s:0><s:0><s:0><s:0><s:0><s:0><s:0><s:0><s:0><s:0><s:0><s:0><s:0><s:0><s:0><s:0><s:0><s:0><s:0><s:0><s:0><s:0><s:0><s:0><s:0><s:0><s:0><s:0><s:0><s:0><s:0><s:0><s:0><s:0><s:0><s:0><s:0><s:0><s:0><s:0><s:0><s:0><s:0><s:0><s:0><s:0><s:0><s:0><s:0><s:0><s:0><s:0><s:0><s:0><s:0><s:0><s:0><s:0><s:0><s:0><s:0><s:0><s:0><s:0><s:0><s:0><s:0><s:0><s:0><s:0><s:0><s:0><s:0><s:0><s:0><s:0><s:0><s:0><s:0><s:0><s:0><s:0><s:0><s:0><s:0><s:0><s:0><s:0><s:0><s:0><s:0><s:0><s:0><s:0><s:0><s:0><s:0><s:0><s:0><s:0><s:0><s:0><s:0><s:0><s:0><s:0><s:0><s:0><s:0><s:0><s:0><s:0><s:0><s:0><s:0><s:0><s:0><s:0><s:0><s:0><s:0><s:0><s:0><s:0><s:0><s:0><s:0><s:0><s:0><s:0><s:0><s:0><s:0><s:0><s:0><s:0><s:0><s:0><s:0><s:0><s:0><s:0><s:0><s:0><s:0><s:0><s:0><s:0><s:0><s:0><s:0><s:0><s:0><s:0><s:0><s:0><s:0><s:0><s:0><s:0><s:0><s:0><s:0><s:0><s:0><s:0><s:0><s:0><s:0><s:0><s:0><s:0><s:0><s:0><s:0><s:0><s:0><s:0><s:0><s:0><s:0><s:0><s:0><s:0><s:0><s:0><s:0><s:0><s:0><s:0><s:0><s:0><s:0><s:0><s:0><s:0><s:0><s:0><s:0><s:0><s:0><s:0><s:0><s:0><s:0><s:0><s:0><s:0><s:0><s:0><s:0><s:0><s:0><s:0><s:0><s:0><s:0><s:0><s:0><s:0><s:0><s:0><s:0><s:0><s:0><s:0><s:0><s:0><s:0><s:0><s:0><s:0><s:0><s:0><s:0><s:0><s:0><s:0><s:0><s:0><s:0><s:0><s:0><s:0><s:0><s:0><s:0><s:0><s:0><s:0><s:0><s:0><s:0><s:0><s:0><s:0><s:0><s:0><s:0><s:0><s:0><s:0><s:0><s:0><s:0><s:0><s:0><s:0><s:0><s:0><s:0><s:0><s:0><s:0><s:0><s:0><s:0><s:0><s:0><s:0><s:0><s:0><s:0><s:0><s:0><s:0><s:0><s:0><s:0><s:0><s:0><s:0><s:0><s:0><s:0><s:0><s:0><s:0><s:0><s:0><s:0><s:0><s:0><s:0><s:0><s:0><s:0><s:0><s:0><s:0><s:0><s:0><s:0><s:0><s:0><s:0><s:0><s:0><s:0><s:0><s:0><s:0><s:0><s:0><s:0><s:0><s:0><s:0><s:0><s:0><s:0><s:0><s:0><s:0><s:0><s:0><s:0><s:0><s:0><s:0><s:0><s:0><s:0><s:0><s:0><s:0><s:0><s:0><s:0><s:0><s:0><s:0><s:0><s:0><s:0><s:0><s:0><s:0><s:0><s:0><s:0><s:0><s:0><s:0><s:0><s:0><s:0><s:0><s:0><s:0><s:0><s:0><s:0><s:0><s:0><s:0><s:0><s:0><s:0><s:0><s:0><s:0><s:0><s:0><s:0><s:0><s:0><s:0><s:0><s:0><s:0><s:0><s:0><s:0><s:0><s:0><s:0><s:0><s:0><s:0><s:0><s:0><s:0><s:0><s:0><s:0><s:0><s:0><s:0><s:0><s:0><s:0><s:0><s:0><s:0><s:0><s:0><s:0><s:0><s:0><s:0><s:0><s:0><s:0><s:0><s:0><s:0><s:0><s:0><s:0><s:0><s:0><s:0><s:0><s:0><s:0><s:0><s:0><s:0><s:0><s:0><s:0><s:0><s:0><s:0><s:0><s:0><s:0><s:0><s:0><s:0><s:0><s:0><s:0><s:0><s:0><s:0><s:0><s:0><s:0><s:0><s:0><s:0><s:0><s:0><s:0><s:0><s:0><s:0><s:0><s:0><s:0><s:0><s:0><s:0><s:0><s:0><s:0><s:0><s:0><s:0><s:0><s:0><s:0><s:0><s:0><s:0><s:0><s:0><s:0><s:0><s:0><s:0><s:0><s:0><s:0><s:0><s:0><s:0><s:0><s:0><s:0><s:0><s:0><s:0><s:0><s:0><s:0><s:0><s:0><s:0><s:0><s:0><s:0><s:0><s:0><s:0><s:0><s:0><s:0><s:0><s:0><s:0><s:0><s:0><s:0><s:0><s:0><s:0><s:0><s:0><s:0><s:0><s:0><s:0><s:0><s:0><s:0><s:0><s:0><s:0><s:0><s:0><s:0><s:0><s:0><s:0><s:0><s:0><s:0><s:0><s:0><s:0><s:0><s:0><s:0><s:0><s:0><s:0><s:0><s:0><s:0><s:0><s:0><s:0><s:0><s:0><s:0><s:0><s:0><s:0><s:0><s:0><s:0><s:0><s:0><s:0><s:0><s:0><s:0><s:0><s:0><s:0><s:0><s:0><s:0><s:0><s:0><s:0><s:0><s:0><s:0><s:0><s:0><s:0><s:0><s:0 ...

# %%
with torch.no_grad():
    audio = model((feature[:, :, 1:-1]-2).cuda())
audio = audio[0, 0].detach().cpu().numpy()
audio = audio / np.max(np.abs(audio))
# sf.write("test.wav", audio, 44100)
display(Audio(data=audio, rate=44100))

# %%
from firefly_decode import FireflyVQ
import torch
import numpy as np
model = FireflyVQ()
model.load_state_dict(torch.load("checkpoints/firefly-vq-8x256-base.pth", map_location='cpu'), strict=True)
model.eval()
model.cuda()
# Out:
# FireflyVQ(
#   (vq): DownsampleResidualVectorQuantize(
#     (quantizers): ModuleList(
#       (0-7): 8 x VectorQuantize(
#         (in_proj): ParametrizedConv1d(
#           512, 8, kernel_size=(1,), stride=(1,)
#           (parametrizations): ModuleDict(
#             (weight): ParametrizationList(
#               (0): _WeightNorm()
#             )
#           )
#         )
#         (out_proj): ParametrizedConv1d(
#           8, 512, kernel_size=(1,), stride=(1,)
#           (parametrizations): ModuleDict(
#             (weight): ParametrizationList(
#               (0): _WeightNorm()
#             )
#           )
#         )
#         (codebook): Embedding(256, 8)
#       )
#     )
#     (downsample): Sequential(
#       (0): Conv1d(512, 512, kernel_size=(2,), stride=(2,))
#       (1): Conv1d(512, 512, kernel_size=(2,), stride=(2,))
#     )
#     (upsample): Sequential(
#       (0): ConvTranspose1d(512, 512, kernel_size=(2,), stride=(2,))
#       (1): ConvTranspose1d(512, 512, kernel_size=(2,), stride=(2,))
#     )
#   )
#   (head): HiFiGANGenerator(
#     (conv_pre): ParametrizedConv1d(
#       512, 512, kernel_size=(13,), stride=(1,), padding=(6,)
#       (parametrizations): ModuleDict(
#         (weight): ParametrizationList(
#           (0): _WeightNorm()
#         )
#       )
#     )
#     (noise_convs): ModuleList(
#       (0): Conv1d(1, 256, kernel_size=(128,), stride=(64,), padding=(32,))
#       (1): Conv1d(1, 128, kernel_size=(16,), stride=(8,), padding=(4,))
#       (2): Conv1d(1, 64, kernel_size=(8,), stride=(4,), padding=(2,))
#       (3): Conv1d(1, 32, kernel_size=(4,), stride=(2,), padding=(1,))
#       (4): Conv1d(1, 16, kernel_size=(1,), stride=(1,))
#     )
#     (ups): ModuleList(
#       (0): ParametrizedConvTranspose1d(
#         512, 256, kernel_size=(16,), stride=(8,), padding=(4,)
#         (parametrizations): ModuleDict(
#           (weight): ParametrizationList(
#             (0): _WeightNorm()
#           )
#         )
#       )
#       (1): ParametrizedConvTranspose1d(
#         256, 128, kernel_size=(16,), stride=(8,), padding=(4,)
#         (parametrizations): ModuleDict(
#           (weight): ParametrizationList(
#             (0): _WeightNorm()
#           )
#         )
#       )
#       (2): ParametrizedConvTranspose1d(
#         128, 64, kernel_size=(4,), stride=(2,), padding=(1,)
#         (parametrizations): ModuleDict(
#           (weight): ParametrizationList(
#             (0): _WeightNorm()
#           )
#         )
#       )
#       (3): ParametrizedConvTranspose1d(
#         64, 32, kernel_size=(4,), stride=(2,), padding=(1,)
#         (parametrizations): ModuleDict(
#           (weight): ParametrizationList(
#             (0): _WeightNorm()
#           )
#         )
#       )
#       (4): ParametrizedConvTranspose1d(
#         32, 16, kernel_size=(4,), stride=(2,), padding=(1,)
#         (parametrizations): ModuleDict(
#           (weight): ParametrizationList(
#             (0): _WeightNorm()
#           )
#         )
#       )
#     )
#     (resblocks): ModuleList(
#       (0): ParralelBlock(
#         (blocks): ModuleList(
#           (0): ResBlock(
#             (convs1): ModuleList(
#               (0): ParametrizedConv1d(
#                 256, 256, kernel_size=(3,), stride=(1,), padding=(1,)
#                 (parametrizations): ModuleDict(
#                   (weight): ParametrizationList(
#                     (0): _WeightNorm()
#                   )
#                 )
#               )
#               (1): ParametrizedConv1d(
#                 256, 256, kernel_size=(3,), stride=(1,), padding=(3,), dilation=(3,)
#                 (parametrizations): ModuleDict(
#                   (weight): ParametrizationList(
#                     (0): _WeightNorm()
#                   )
#                 )
#               )
#               (2): ParametrizedConv1d(
#                 256, 256, kernel_size=(3,), stride=(1,), padding=(5,), dilation=(5,)
#                 (parametrizations): ModuleDict(
#                   (weight): ParametrizationList(
#                     (0): _WeightNorm()
#                   )
#                 )
#               )
#             )
#             (convs2): ModuleList(
#               (0-2): 3 x ParametrizedConv1d(
#                 256, 256, kernel_size=(3,), stride=(1,), padding=(1,)
#                 (parametrizations): ModuleDict(
#                   (weight): ParametrizationList(
#                     (0): _WeightNorm()
#                   )
#                 )
#               )
#             )
#           )
#           (1): ResBlock(
#             (convs1): ModuleList(
#               (0): ParametrizedConv1d(
#                 256, 256, kernel_size=(7,), stride=(1,), padding=(3,)
#                 (parametrizations): ModuleDict(
#                   (weight): ParametrizationList(
#                     (0): _WeightNorm()
#                   )
#                 )
#               )
#               (1): ParametrizedConv1d(
#                 256, 256, kernel_size=(7,), stride=(1,), padding=(9,), dilation=(3,)
#                 (parametrizations): ModuleDict(
#                   (weight): ParametrizationList(
#                     (0): _WeightNorm()
#                   )
#                 )
#               )
#               (2): ParametrizedConv1d(
#                 256, 256, kernel_size=(7,), stride=(1,), padding=(15,), dilation=(5,)
#                 (parametrizations): ModuleDict(
#                   (weight): ParametrizationList(
#                     (0): _WeightNorm()
#                   )
#                 )
#               )
#             )
#             (convs2): ModuleList(
#               (0-2): 3 x ParametrizedConv1d(
#                 256, 256, kernel_size=(7,), stride=(1,), padding=(3,)
#                 (parametrizations): ModuleDict(
#                   (weight): ParametrizationList(
#                     (0): _WeightNorm()
#                   )
#                 )
#               )
#             )
#           )
#           (2): ResBlock(
#             (convs1): ModuleList(
#               (0): ParametrizedConv1d(
#                 256, 256, kernel_size=(11,), stride=(1,), padding=(5,)
#                 (parametrizations): ModuleDict(
#                   (weight): ParametrizationList(
#                     (0): _WeightNorm()
#                   )
#                 )
#               )
#               (1): ParametrizedConv1d(
#                 256, 256, kernel_size=(11,), stride=(1,), padding=(15,), dilation=(3,)
#                 (parametrizations): ModuleDict(
#                   (weight): ParametrizationList(
#                     (0): _WeightNorm()
#                   )
#                 )
#               )
#               (2): ParametrizedConv1d(
#                 256, 256, kernel_size=(11,), stride=(1,), padding=(25,), dilation=(5,)
#                 (parametrizations): ModuleDict(
#                   (weight): ParametrizationList(
#                     (0): _WeightNorm()
#                   )
#                 )
#               )
#             )
#             (convs2): ModuleList(
#               (0-2): 3 x ParametrizedConv1d(
#                 256, 256, kernel_size=(11,), stride=(1,), padding=(5,)
#                 (parametrizations): ModuleDict(
#                   (weight): ParametrizationList(
#                     (0): _WeightNorm()
#                   )
#                 )
#               )
#             )
#           )
#         )
#       )
#       (1): ParralelBlock(
#         (blocks): ModuleList(
#           (0): ResBlock(
#             (convs1): ModuleList(
#               (0): ParametrizedConv1d(
#                 128, 128, kernel_size=(3,), stride=(1,), padding=(1,)
#                 (parametrizations): ModuleDict(
#                   (weight): ParametrizationList(
#                     (0): _WeightNorm()
#                   )
#                 )
#               )
#               (1): ParametrizedConv1d(
#                 128, 128, kernel_size=(3,), stride=(1,), padding=(3,), dilation=(3,)
#                 (parametrizations): ModuleDict(
#                   (weight): ParametrizationList(
#                     (0): _WeightNorm()
#                   )
#                 )
#               )
#               (2): ParametrizedConv1d(
#                 128, 128, kernel_size=(3,), stride=(1,), padding=(5,), dilation=(5,)
#                 (parametrizations): ModuleDict(
#                   (weight): ParametrizationList(
#                     (0): _WeightNorm()
#                   )
#                 )
#               )
#             )
#             (convs2): ModuleList(
#               (0-2): 3 x ParametrizedConv1d(
#                 128, 128, kernel_size=(3,), stride=(1,), padding=(1,)
#                 (parametrizations): ModuleDict(
#                   (weight): ParametrizationList(
#                     (0): _WeightNorm()
#                   )
#                 )
#               )
#             )
#           )
#           (1): ResBlock(
#             (convs1): ModuleList(
#               (0): ParametrizedConv1d(
#                 128, 128, kernel_size=(7,), stride=(1,), padding=(3,)
#                 (parametrizations): ModuleDict(
#                   (weight): ParametrizationList(
#                     (0): _WeightNorm()
#                   )
#                 )
#               )
#               (1): ParametrizedConv1d(
#                 128, 128, kernel_size=(7,), stride=(1,), padding=(9,), dilation=(3,)
#                 (parametrizations): ModuleDict(
#                   (weight): ParametrizationList(
#                     (0): _WeightNorm()
#                   )
#                 )
#               )
#               (2): ParametrizedConv1d(
#                 128, 128, kernel_size=(7,), stride=(1,), padding=(15,), dilation=(5,)
#                 (parametrizations): ModuleDict(
#                   (weight): ParametrizationList(
#                     (0): _WeightNorm()
#                   )
#                 )
#               )
#             )
#             (convs2): ModuleList(
#               (0-2): 3 x ParametrizedConv1d(
#                 128, 128, kernel_size=(7,), stride=(1,), padding=(3,)
#                 (parametrizations): ModuleDict(
#                   (weight): ParametrizationList(
#                     (0): _WeightNorm()
#                   )
#                 )
#               )
#             )
#           )
#           (2): ResBlock(
#             (convs1): ModuleList(
#               (0): ParametrizedConv1d(
#                 128, 128, kernel_size=(11,), stride=(1,), padding=(5,)
#                 (parametrizations): ModuleDict(
#                   (weight): ParametrizationList(
#                     (0): _WeightNorm()
#                   )
#                 )
#               )
#               (1): ParametrizedConv1d(
#                 128, 128, kernel_size=(11,), stride=(1,), padding=(15,), dilation=(3,)
#                 (parametrizations): ModuleDict(
#                   (weight): ParametrizationList(
#                     (0): _WeightNorm()
#                   )
#                 )
#               )
#               (2): ParametrizedConv1d(
#                 128, 128, kernel_size=(11,), stride=(1,), padding=(25,), dilation=(5,)
#                 (parametrizations): ModuleDict(
#                   (weight): ParametrizationList(
#                     (0): _WeightNorm()
#                   )
#                 )
#               )
#             )
#             (convs2): ModuleList(
#               (0-2): 3 x ParametrizedConv1d(
#                 128, 128, kernel_size=(11,), stride=(1,), padding=(5,)
#                 (parametrizations): ModuleDict(
#                   (weight): ParametrizationList(
#                     (0): _WeightNorm()
#                   )
#                 )
#               )
#             )
#           )
#         )
#       )
#       (2): ParralelBlock(
#         (blocks): ModuleList(
#           (0): ResBlock(
#             (convs1): ModuleList(
#               (0): ParametrizedConv1d(
#                 64, 64, kernel_size=(3,), stride=(1,), padding=(1,)
#                 (parametrizations): ModuleDict(
#                   (weight): ParametrizationList(
#                     (0): _WeightNorm()
#                   )
#                 )
#               )
#               (1): ParametrizedConv1d(
#                 64, 64, kernel_size=(3,), stride=(1,), padding=(3,), dilation=(3,)
#                 (parametrizations): ModuleDict(
#                   (weight): ParametrizationList(
#                     (0): _WeightNorm()
#                   )
#                 )
#               )
#               (2): ParametrizedConv1d(
#                 64, 64, kernel_size=(3,), stride=(1,), padding=(5,), dilation=(5,)
#                 (parametrizations): ModuleDict(
#                   (weight): ParametrizationList(
#                     (0): _WeightNorm()
#                   )
#                 )
#               )
#             )
#             (convs2): ModuleList(
#               (0-2): 3 x ParametrizedConv1d(
#                 64, 64, kernel_size=(3,), stride=(1,), padding=(1,)
#                 (parametrizations): ModuleDict(
#                   (weight): ParametrizationList(
#                     (0): _WeightNorm()
#                   )
#                 )
#               )
#             )
#           )
#           (1): ResBlock(
#             (convs1): ModuleList(
#               (0): ParametrizedConv1d(
#                 64, 64, kernel_size=(7,), stride=(1,), padding=(3,)
#                 (parametrizations): ModuleDict(
#                   (weight): ParametrizationList(
#                     (0): _WeightNorm()
#                   )
#                 )
#               )
#               (1): ParametrizedConv1d(
#                 64, 64, kernel_size=(7,), stride=(1,), padding=(9,), dilation=(3,)
#                 (parametrizations): ModuleDict(
#                   (weight): ParametrizationList(
#                     (0): _WeightNorm()
#                   )
#                 )
#               )
#               (2): ParametrizedConv1d(
#                 64, 64, kernel_size=(7,), stride=(1,), padding=(15,), dilation=(5,)
#                 (parametrizations): ModuleDict(
#                   (weight): ParametrizationList(
#                     (0): _WeightNorm()
#                   )
#                 )
#               )
#             )
#             (convs2): ModuleList(
#               (0-2): 3 x ParametrizedConv1d(
#                 64, 64, kernel_size=(7,), stride=(1,), padding=(3,)
#                 (parametrizations): ModuleDict(
#                   (weight): ParametrizationList(
#                     (0): _WeightNorm()
#                   )
#                 )
#               )
#             )
#           )
#           (2): ResBlock(
#             (convs1): ModuleList(
#               (0): ParametrizedConv1d(
#                 64, 64, kernel_size=(11,), stride=(1,), padding=(5,)
#                 (parametrizations): ModuleDict(
#                   (weight): ParametrizationList(
#                     (0): _WeightNorm()
#                   )
#                 )
#               )
#               (1): ParametrizedConv1d(
#                 64, 64, kernel_size=(11,), stride=(1,), padding=(15,), dilation=(3,)
#                 (parametrizations): ModuleDict(
#                   (weight): ParametrizationList(
#                     (0): _WeightNorm()
#                   )
#                 )
#               )
#               (2): ParametrizedConv1d(
#                 64, 64, kernel_size=(11,), stride=(1,), padding=(25,), dilation=(5,)
#                 (parametrizations): ModuleDict(
#                   (weight): ParametrizationList(
#                     (0): _WeightNorm()
#                   )
#                 )
#               )
#             )
#             (convs2): ModuleList(
#               (0-2): 3 x ParametrizedConv1d(
#                 64, 64, kernel_size=(11,), stride=(1,), padding=(5,)
#                 (parametrizations): ModuleDict(
#                   (weight): ParametrizationList(
#                     (0): _WeightNorm()
#                   )
#                 )
#               )
#             )
#           )
#         )
#       )
#       (3): ParralelBlock(
#         (blocks): ModuleList(
#           (0): ResBlock(
#             (convs1): ModuleList(
#               (0): ParametrizedConv1d(
#                 32, 32, kernel_size=(3,), stride=(1,), padding=(1,)
#                 (parametrizations): ModuleDict(
#                   (weight): ParametrizationList(
#                     (0): _WeightNorm()
#                   )
#                 )
#               )
#               (1): ParametrizedConv1d(
#                 32, 32, kernel_size=(3,), stride=(1,), padding=(3,), dilation=(3,)
#                 (parametrizations): ModuleDict(
#                   (weight): ParametrizationList(
#                     (0): _WeightNorm()
#                   )
#                 )
#               )
#               (2): ParametrizedConv1d(
#                 32, 32, kernel_size=(3,), stride=(1,), padding=(5,), dilation=(5,)
#                 (parametrizations): ModuleDict(
#                   (weight): ParametrizationList(
#                     (0): _WeightNorm()
#                   )
#                 )
#               )
#             )
#             (convs2): ModuleList(
#               (0-2): 3 x ParametrizedConv1d(
#                 32, 32, kernel_size=(3,), stride=(1,), padding=(1,)
#                 (parametrizations): ModuleDict(
#                   (weight): ParametrizationList(
#                     (0): _WeightNorm()
#                   )
#                 )
#               )
#             )
#           )
#           (1): ResBlock(
#             (convs1): ModuleList(
#               (0): ParametrizedConv1d(
#                 32, 32, kernel_size=(7,), stride=(1,), padding=(3,)
#                 (parametrizations): ModuleDict(
#                   (weight): ParametrizationList(
#                     (0): _WeightNorm()
#                   )
#                 )
#               )
#               (1): ParametrizedConv1d(
#                 32, 32, kernel_size=(7,), stride=(1,), padding=(9,), dilation=(3,)
#                 (parametrizations): ModuleDict(
#                   (weight): ParametrizationList(
#                     (0): _WeightNorm()
#                   )
#                 )
#               )
#               (2): ParametrizedConv1d(
#                 32, 32, kernel_size=(7,), stride=(1,), padding=(15,), dilation=(5,)
#                 (parametrizations): ModuleDict(
#                   (weight): ParametrizationList(
#                     (0): _WeightNorm()
#                   )
#                 )
#               )
#             )
#             (convs2): ModuleList(
#               (0-2): 3 x ParametrizedConv1d(
#                 32, 32, kernel_size=(7,), stride=(1,), padding=(3,)
#                 (parametrizations): ModuleDict(
#                   (weight): ParametrizationList(
#                     (0): _WeightNorm()
#                   )
#                 )
#               )
#             )
#           )
#           (2): ResBlock(
#             (convs1): ModuleList(
#               (0): ParametrizedConv1d(
#                 32, 32, kernel_size=(11,), stride=(1,), padding=(5,)
#                 (parametrizations): ModuleDict(
#                   (weight): ParametrizationList(
#                     (0): _WeightNorm()
#                   )
#                 )
#               )
#               (1): ParametrizedConv1d(
#                 32, 32, kernel_size=(11,), stride=(1,), padding=(15,), dilation=(3,)
#                 (parametrizations): ModuleDict(
#                   (weight): ParametrizationList(
#                     (0): _WeightNorm()
#                   )
#                 )
#               )
#               (2): ParametrizedConv1d(
#                 32, 32, kernel_size=(11,), stride=(1,), padding=(25,), dilation=(5,)
#                 (parametrizations): ModuleDict(
#                   (weight): ParametrizationList(
#                     (0): _WeightNorm()
#                   )
#                 )
#               )
#             )
#             (convs2): ModuleList(
#               (0-2): 3 x ParametrizedConv1d(
#                 32, 32, kernel_size=(11,), stride=(1,), padding=(5,)
#                 (parametrizations): ModuleDict(
#                   (weight): ParametrizationList(
#                     (0): _WeightNorm()
#                   )
#                 )
#               )
#             )
#           )
#         )
#       )
#       (4): ParralelBlock(
#         (blocks): ModuleList(
#           (0): ResBlock(
#             (convs1): ModuleList(
#               (0): ParametrizedConv1d(
#                 16, 16, kernel_size=(3,), stride=(1,), padding=(1,)
#                 (parametrizations): ModuleDict(
#                   (weight): ParametrizationList(
#                     (0): _WeightNorm()
#                   )
#                 )
#               )
#               (1): ParametrizedConv1d(
#                 16, 16, kernel_size=(3,), stride=(1,), padding=(3,), dilation=(3,)
#                 (parametrizations): ModuleDict(
#                   (weight): ParametrizationList(
#                     (0): _WeightNorm()
#                   )
#                 )
#               )
#               (2): ParametrizedConv1d(
#                 16, 16, kernel_size=(3,), stride=(1,), padding=(5,), dilation=(5,)
#                 (parametrizations): ModuleDict(
#                   (weight): ParametrizationList(
#                     (0): _WeightNorm()
#                   )
#                 )
#               )
#             )
#             (convs2): ModuleList(
#               (0-2): 3 x ParametrizedConv1d(
#                 16, 16, kernel_size=(3,), stride=(1,), padding=(1,)
#                 (parametrizations): ModuleDict(
#                   (weight): ParametrizationList(
#                     (0): _WeightNorm()
#                   )
#                 )
#               )
#             )
#           )
#           (1): ResBlock(
#             (convs1): ModuleList(
#               (0): ParametrizedConv1d(
#                 16, 16, kernel_size=(7,), stride=(1,), padding=(3,)
#                 (parametrizations): ModuleDict(
#                   (weight): ParametrizationList(
#                     (0): _WeightNorm()
#                   )
#                 )
#               )
#               (1): ParametrizedConv1d(
#                 16, 16, kernel_size=(7,), stride=(1,), padding=(9,), dilation=(3,)
#                 (parametrizations): ModuleDict(
#                   (weight): ParametrizationList(
#                     (0): _WeightNorm()
#                   )
#                 )
#               )
#               (2): ParametrizedConv1d(
#                 16, 16, kernel_size=(7,), stride=(1,), padding=(15,), dilation=(5,)
#                 (parametrizations): ModuleDict(
#                   (weight): ParametrizationList(
#                     (0): _WeightNorm()
#                   )
#                 )
#               )
#             )
#             (convs2): ModuleList(
#               (0-2): 3 x ParametrizedConv1d(
#                 16, 16, kernel_size=(7,), stride=(1,), padding=(3,)
#                 (parametrizations): ModuleDict(
#                   (weight): ParametrizationList(
#                     (0): _WeightNorm()
#                   )
#                 )
#               )
#             )
#           )
#           (2): ResBlock(
#             (convs1): ModuleList(
#               (0): ParametrizedConv1d(
#                 16, 16, kernel_size=(11,), stride=(1,), padding=(5,)
#                 (parametrizations): ModuleDict(
#                   (weight): ParametrizationList(
#                     (0): _WeightNorm()
#                   )
#                 )
#               )
#               (1): ParametrizedConv1d(
#                 16, 16, kernel_size=(11,), stride=(1,), padding=(15,), dilation=(3,)
#                 (parametrizations): ModuleDict(
#                   (weight): ParametrizationList(
#                     (0): _WeightNorm()
#                   )
#                 )
#               )
#               (2): ParametrizedConv1d(
#                 16, 16, kernel_size=(11,), stride=(1,), padding=(25,), dilation=(5,)
#                 (parametrizations): ModuleDict(
#                   (weight): ParametrizationList(
#                     (0): _WeightNorm()
#                   )
#                 )
#               )
#             )
#             (convs2): ModuleList(
#               (0-2): 3 x ParametrizedConv1d(
#                 16, 16, kernel_size=(11,), stride=(1,), padding=(5,)
#                 (parametrizations): ModuleDict(
#                   (weight): ParametrizationList(
#                     (0): _WeightNorm()
#                   )
#                 )
#               )
#             )
#           )
#         )
#       )
#     )
#     (activation_post): SiLU(inplace=True)
#     (conv_post): ParametrizedConv1d(
#       16, 1, kernel_size=(13,), stride=(1,), padding=(6,)
#       (parametrizations): ModuleDict(
#         (weight): ParametrizationList(
#           (0): _WeightNorm()
#         )
#       )
#     )
#   )
# )

# %%
# !ls ./test
# Out:
# 4e7dbe3ef49ad53d.npy  4e7dbe3ef49ad53d.wav
# huggingface/tokenizers: The current process just got forked, after parallelism has already been used. Disabling parallelism to avoid deadlocks...
# To disable this warning, you can either:
# 	- Avoid using `tokenizers` before the fork if possible
# 	- Explicitly set the environment variable TOKENIZERS_PARALLELISM=(true | false)
